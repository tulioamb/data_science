# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats

df = pd.read_csv('all_data.csv')
# print(df.head())
# print(len(df))
print(df.groupby(['Country'])['Life expectancy at birth (years)'].count())
# print(df.describe())
# print(df.info())
# Out:
# Country
# Chile                       16
# China                       16
# Germany                     16
# Mexico                      16
# United States of America    16
# Zimbabwe                    16
# Name: Life expectancy at birth (years), dtype: int64

# %%
countries = df.Country.unique()
index = 1
for country in countries:
    plt.subplot(1, 2, index)
    plt.plot(df.Year[df.Country == country], df['Life expectancy at birth (years)'][df.Country == country])
    plt.title('{}'.format(country))
    if index % 2 == 0:
        index = 1
        plt.subplots_adjust(wspace = .5)
        plt.show()
        plt.clf()
        plt.figure()
    else:
        index += 1
# plt.show()
# plt.plot(df.Year[df.Country == 'Zimbabwe'], df['Life expectancy at birth (years)'][df.Country == 'Zimbabwe'])
# plt.show()
# plt.clf()

# %%
for country in countries:
#     sns.scatterplot(x = 'GDP', y = 'Life expectancy at birth (years)', data = df[df.Country == country])
    sns.lmplot(x = 'GDP', y = 'Life expectancy at birth (years)', data = df[df.Country == country])
    plt.title('{}\nCorrelation: {}'.format(country, round(corr, 2)))
    corr, p = stats.pearsonr(df[df.Country == country].GDP, df[df.Country == country]['Life expectancy at birth (years)'])
    plt.show()
    plt.clf()

# %%
print('testing')
